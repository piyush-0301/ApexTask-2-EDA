# %%
import pandas as pd

df = pd.read_csv('mall_customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   49                  22                      12
# 1           2  Female   56                  41                      25
# 2           3    Male   66                  41                      52
# 3           4    Male   69                  35                      85
# 4           5    Male   49                  44                      53

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   44.405000           81.215000               47.690000
# std     57.879185   15.353816           38.864134               28.355849
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   32.750000           46.000000               23.000000
# 50%    100.500000   46.000000           80.500000               47.000000
# 75%    150.250000   56.000000          114.000000               73.000000
# max    200.000000   69.000000          149.000000               99.000000

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      100
# Female    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Age'].hist()
plt.title("Age Distribution")
plt.show()

# %%
df['Spending Score (1-100)'].hist()
plt.title("Spending Score Distribution")
plt.show()

# %% [markdown]
# BUSINESS QUESTIONS

# %% [markdown]
# Which gender spends more?

# %%
df.groupby('Gender')['Spending Score (1-100)'].mean()
# Out:
# Gender
# Female    47.47
# Male      47.91
# Name: Spending Score (1-100), dtype: float64

# %% [markdown]
# Which age group spends more?

# %%
df.groupby(pd.cut(df['Age'], bins=[18,30,45,60,80]))['Spending Score (1-100)'].mean()
# Out:
# /tmp/ipykernel_9572/4027434166.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df['Age'], bins=[18,30,45,60,80]))['Spending Score (1-100)'].mean()
# Age
# (18, 30]    47.023256
# (30, 45]    47.500000
# (45, 60]    49.187500
# (60, 80]    46.405405
# Name: Spending Score (1-100), dtype: float64

# %% [markdown]
# High income vs spending?

# %%
import seaborn as sns

sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', data=df)
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %% [markdown]
# **Income** vs **Spending**

# %%
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %% [markdown]
# Age vs Spending

# %%
sns.scatterplot(x='Age', y='Spending Score (1-100)', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Spending Score (1-100)'>

# %%
df.to_csv("eda_processed.csv", index=False)
